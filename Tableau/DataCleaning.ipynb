# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "TripData_2018.csv"

# Read Purchasing File and store into Pandas data frame
Trip_Data = pd.read_csv(file_to_load)
Trip_Data.head()
# Out:
#    tripduration              starttime               stoptime  \
# 0           254  11/1/2018 12:00:13 AM  11/1/2018 12:04:27 AM
# 1           833  11/1/2018 12:00:16 AM  11/1/2018 12:14:09 AM
# 2           683  11/1/2018 12:00:18 AM  11/1/2018 12:11:41 AM
# 3          1840  11/1/2018 12:00:19 AM  11/1/2018 12:30:59 AM
# 4          1212  11/1/2018 12:00:47 AM  11/1/2018 12:21:00 AM
#
#    start station id            start station name  start station latitude  \
# 0            3522.0                37 St & 24 Ave               40.770148
# 1             252.0  MacDougal St & Washington Sq               40.732264
# 2            3405.0                  5 St & 6 Ave               40.670484
# 3            3150.0            E 85 St & York Ave               40.775369
# 4             325.0               E 19 St & 3 Ave               40.736245
#
#    start station longitude  end station id             end station name  \
# ...

# %%
Clean_Trip_Data = Trip_Data.dropna()
Clean_Trip_Data.head(15)
# Out:
#     tripduration              starttime               stoptime  \
# 0            254  11/1/2018 12:00:13 AM  11/1/2018 12:04:27 AM
# 1            833  11/1/2018 12:00:16 AM  11/1/2018 12:14:09 AM
# 2            683  11/1/2018 12:00:18 AM  11/1/2018 12:11:41 AM
# 3           1840  11/1/2018 12:00:19 AM  11/1/2018 12:30:59 AM
# 4           1212  11/1/2018 12:00:47 AM  11/1/2018 12:21:00 AM
# 5            792  11/1/2018 12:01:08 AM  11/1/2018 12:14:20 AM
# 6            243  11/1/2018 12:01:12 AM  11/1/2018 12:05:15 AM
# 7            460  11/1/2018 12:01:12 AM  11/1/2018 12:08:53 AM
# 8            778  11/1/2018 12:01:15 AM  11/1/2018 12:14:13 AM
# 9            178  11/1/2018 12:01:32 AM  11/1/2018 12:04:30 AM
# 10           547  11/1/2018 12:01:22 AM  11/1/2018 12:10:29 AM
# 11           761  11/1/2018 12:01:26 AM  11/1/2018 12:14:08 AM
# 12           191  11/1/2018 12:01:32 AM  11/1/2018 12:04:44 AM
# 13           315  11/1/2018 12:01:34 AM  11/1/2018 12:06:50 AM
# ...

# %%
Clean_Trip_Data.to_csv('Clean_Trip_Data.csv',index=True,header=True)
